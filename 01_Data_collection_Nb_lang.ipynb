# %% [markdown]
# <a href="https://colab.research.google.com/github/miczkejedrzej/MNLP-project-1/blob/main/01_Data_collection_Nb_lang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade wikidata --quiet
# !pip install certifi --upgrade --quiet

# Import of the training data

from google.colab import files

# Import of moduls

import requests
import certifi
import json
import matplotlib.pyplot as plt
import pandas as pd
from wikidata.client import Client
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from google.colab import drive
drive.mount('/content/drive')
import pandas as pd

train_df = pd.read_csv('/content/drive/MyDrive/France_Poland_multilanguage_shared_folder/[MNLP 2025 HW1] train set [PUBLIC] - train_cleaned.tsv',sep='\t')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Training dataset

# %%
# Loading the data
train_df = pd.read_csv('[MNLP 2025 HW1] train set [PUBLIC] - train_cleaned.tsv', sep='\t')

# %%
def extract_entity_id(url):
  """
  Function that extract the identity of an item, thanks to its wikidata link page
  """
  return url.strip().split("/")[-1]



def get_nb_lang(wikidata_url):

  """
  Function that computes the number of languages in wich the entity page is defined
  """

  # Extract the id of the item
  entity_id = extract_entity_id(wikidata_url)

  #Extract informations of the item
  client = Client()
  try:
    item = client.get(entity_id, load=True)
    # counting in how many languages the item has a lable defined
    labels = item.data.get("labels", {})
    return len(labels.keys())
  except:
    return None

# %%
# Application to the whole dataset
train_df['nb_lang'] = train_df['item'].apply(lambda x: get_nb_lang(x))

# %%
# Sanity check
train_df
# Out:
#                                         item                name  \
# 0        http://www.wikidata.org/entity/Q306    Sebastián Piñera
# 1      http://www.wikidata.org/entity/Q12735  John Amos Comenius
# 2       http://www.wikidata.org/entity/Q1752            Macrinus
# 3       http://www.wikidata.org/entity/Q1639        Lamine Diack
# 4       http://www.wikidata.org/entity/Q9588       Richard Nixon
# ...                                      ...                 ...
# 6246  http://www.wikidata.org/entity/Q321103                Bühl
# 6247  http://www.wikidata.org/entity/Q338167          Tenderloin
# 6248   http://www.wikidata.org/entity/Q66991     Schinznach-Dorf
# 6249   http://www.wikidata.org/entity/Q66922             Ependes
# 6250   http://www.wikidata.org/entity/Q67094         Kaiserstuhl
#
#                                             description    type   category  \
# 0       Chilean entrepreneur and politician (1949–2024)  entity   politics
# ...

# %%
# Exportation

train_df.to_json("train_df_lang.json", orient="records", lines=True)
files.download('train_df_lang.json')

# %% [markdown]
# # Dev dataset

# %%
dev_df = pd.read_csv('/content/drive/MyDrive/France_Poland_multilanguage_shared_folder/validation_df.csv', index_col=0)

# %%
# Application to the whole dataset
dev_df['nb_lang'] = dev_df['item'].apply(lambda x: get_nb_lang(x))

# %%
# Visualisation
dev_df
# Out:
#                                        item                name  \
# 0     http://www.wikidata.org/entity/Q15786      1. FC Nürnberg
# 1    http://www.wikidata.org/entity/Q268530          77 Records
# 2    http://www.wikidata.org/entity/Q216153        A Bug's Life
# 3       http://www.wikidata.org/entity/Q593        A Gang Story
# 4    http://www.wikidata.org/entity/Q192185       Aaron Copland
# ..                                      ...                 ...
# 295   http://www.wikidata.org/entity/Q36180              writer
# 296  http://www.wikidata.org/entity/Q156316  Würzburg Residence
# 297   http://www.wikidata.org/entity/Q56911               xunfu
# 298     http://www.wikidata.org/entity/Q377        Yanka Kupala
# 299  http://www.wikidata.org/entity/Q615394                 Yếm
#
#                                            description     type  \
# 0       German sports club based in Nuremberg, Bavaria   entity
# 1                                      UK record label   entity
# ...

# %%
# Exportation

dev_df.to_json("dev_df_lang.json", orient="records", lines=True)
files.download('dev_df_lang.json')
