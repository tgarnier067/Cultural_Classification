# %% [markdown]
# <a href="https://colab.research.google.com/github/miczkejedrzej/MNLP-project-1/blob/main/Visualisation_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f95f721d-6aa7-40a9-b9d2-7b188056e4e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f95f721d-6aa7-40a9-b9d2-7b188056e4e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
train_df_complete = pd.read_json('train_df_complete.json', orient="records", lines=True)

# %%
train_df_complete
# Out:
#                                         item                name  \
# 0        http://www.wikidata.org/entity/Q306    Sebastián Piñera
# 1      http://www.wikidata.org/entity/Q12735  John Amos Comenius
# 2       http://www.wikidata.org/entity/Q1752            Macrinus
# 3       http://www.wikidata.org/entity/Q1639        Lamine Diack
# 4       http://www.wikidata.org/entity/Q9588       Richard Nixon
# ...                                      ...                 ...
# 6246  http://www.wikidata.org/entity/Q321103                Bühl
# 6247  http://www.wikidata.org/entity/Q338167          Tenderloin
# 6248   http://www.wikidata.org/entity/Q66991     Schinznach-Dorf
# 6249   http://www.wikidata.org/entity/Q66922             Ependes
# 6250   http://www.wikidata.org/entity/Q67094         Kaiserstuhl
#
#                                             description    type  \
# 0       Chilean entrepreneur and politician (1949–2024)  entity
# ...

# %% [markdown]
# # Plots

# %% [markdown]
# ## Type
